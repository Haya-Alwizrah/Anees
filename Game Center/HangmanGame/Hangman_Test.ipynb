# %% [markdown]
# # تجربة لعبة الحروف (Hangman) — إحدى ألعاب Game Center
#
# شغّلي الخلية اللي تحت أول شي، وارفعي ملفين لما يطلب منك: `hangman_game.py` و `hangman_words.json`.

# %%
from google.colab import files
uploaded = files.upload()  # اختاري hangman_game.py و hangman_words.json

# %%
from hangman_game import HangmanGame

game = HangmanGame()
print(len(game.wordlist), "كلمة محمّلة")

# %% [markdown]
# شغّلي الخلية اللي تحت لبدء اللعبة (بتطلب منك تدخلين حرف بكل دور).

# %%
game.start()
