# %%
import os
from src.rag import StoryGenerator

# %%
data_path = "datasets\\Formatted-MSA-prompts-stories-for-fine-tuning.csv"
groq_key = os.getenv("GROQ_KEY")
model_name = "openai/gpt-oss-20b"

# %%
sg = StoryGenerator(data_path, groq_key, model_name)

# %%
sg.prepare()
# Out:
# creat or get collection
# Loading embedding_func...
# WARNING:tensorflow:From c:\Users\computer\AppData\Local\Programs\Python\Python312\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# embedding_func loaded.
# Collection 'stories' is ready.
# BM25 index built.
# Existing collection loaded.

# %%
import random

# %%
topic = ["الصداقة", "الصدق", "التعاون", "احترام الوالدين", "مساعدة الآخرين", "المسؤولية", "التسامح", "النظافة"]
t = random.choice(topic)

character = ["أرنب", "أسد", "غزال", "نمر"]
c = random.choice(character)

# %%
story_1 = sg.generate_story(search_t=5, topic= t, character=c)
print(story_1)
# Out:
# Loading reranker...
# Reranker loaded.
# في حديقة خضراء، كان هناك أرنب صغير يدعى فوزي يحب جمع الجزر الطازج. كان فوزي يحاول الوصول إلى الجزر الذي كان ناطقًا على شجرة عالية، لكنه لا يستطيع القفز بما فيه الكفاية. رأى فوزي أصدقائه الأرنب ليلى، والثعلب رامي، والسلحفاة فاطمة، وهم يتجولون في الحديقة. فوزي شرح لهم المشكلة وقال: "لا أستطيع جمع الجزر وحدي، أحتاج إلى مساعدة." ليلى اقترحت أن يجمعوا قطعًا من الخشب ليصنعوا سلمًا، بينما رامي يحمل الجزر، وفاطمة تساعد في وضع الخشب. عملوا معًا، وبفضل جهودهم المشتركة، بنوا سلمًا قويًا يستطيع فوزي والقفز عليه بأمان. عندما وصل فوزي إلى الجزر، جمع كمية كبيرة وأخذها مع أصدقائه ليشاركهم. جميع الأصدقاء جربوا الجزر الطازج، وكانوا سعداء لأنهم شاركوا في الفرح. فوزي شكر أصدقاءه وقال: "العمل الجماعي يجعل المهمة أسهل ويجعل الفرح أكبر." ومن ذلك اليوم، تعلمت حديقة الأرنب أن التعاون بين الأصدقاء هو سر النجاح والسرور.

# %%
qa = sg.generate_QA(story_1)
print(qa)
# Out:
# ```json
# {
#     "questions": [
#         {
#             "id": 1,
#             "question": "لماذا لم يستطع فوزي جمع الجزر وحده؟",
#             "c_answer": "لأنه لا يستطيع القفز إلى الجزر العالي",
#             "w_answer": [
#                 "لأنه لا يعرف كيف يقطف الجزر",
#                 "لأنه لا يحب الجزر",
#                 "لأنه لا يملك أداة"
#             ]
#         },
#         {
#             "id": 2,
#             "question": "من الذي حمل الجزر في القصة؟",
#             "c_answer": "رامي",
#             "w_answer": [
#                 "ليلى",
#                 "فاطمة",
#                 "فوزي"
#             ]
#         },
#         {
#             "id": 3,
#             "question": "ماذا بنوا الأصدقاء لمساعدة فوزي؟",
#             "c_answer": "سلم",
#             "w_answer": [
#                 "جسر",
#                 "سلة",
#                 "أرضية"
#             ]
#         },
#         {
#             "id": 4,
#             "question": "ماذا حدث عندما جمع فوزي الجزر؟",
#             "c_answer": "شارك الجزر مع أصدقائه",
#             "w_answer": [
#                 "أخذه لنفسه",
#                 "أكله وحده",
#                 "وضعه في الحديقة"
#             ]
#         },
#         {
#             "id": 5,
#             "question": "ما هو الدرس الذي تعلمه فوزي من هذه التجربة؟",
#             "c_answer": "العمل الجماعي يجعل المهمة أسهل ويجعل الفرح أكبر",
#             "w_answer": [
#                 "القفز أفضل من البناء",
#                 "الجزر نادر",
#                 "الأصدقاء لا يساعدون"
#             ]
#         }
#     ]
# }
# ```

# %%
ex = sg.explain_words(story_1)
print(ex)
# Out:
# {
#     "words": [
#         {
#             "word": "ناطقًا",
#             "meaning": "يُظهر كلامًا، مثل حيوان يُتَكَلَّم."
#         },
#         {
#             "word": "الثعلب",
#             "meaning": "حيوان ذكي وأنيق يعيش في الغابة."
#         },
#         {
#             "word": "السلحفاة",
#             "meaning": "حيوان بطيء يحمل بيتًا على ظهره."
#         },
#         {
#             "word": "يتجولون",
#             "meaning": "يمشون في الحديقة ببطء."
#         },
#         {
#             "word": "شرح",
#             "meaning": "يُوضِّح أو يُفسِّر شيئًا."
#         },
#         {
#             "word": "المشكلة",
#             "meaning": "صعوبة أو شيء يحتاج لحل."
#         },
#         {
#             "word": "قطعًا",
#             "meaning": "قطاعات صغيرة من شيء، مثل الخشب."
#         },
#         {
#             "word": "الخشب",
#             "meaning": "مادة من شجرة تُستخدم لبناء الأشياء."
#         },
#         {
#             "word": "سلمًا",
#             "meaning": "سلسلة من الدرجات تُستخدم للصعود."
#         },
#         {
#             "

# %%
from groq import Groq
import os

client = Groq(api_key=os.getenv("GROQ_KEY"))

models = client.models.list()

for model in models.data:
    print(model.id)
# Out:
# canopylabs/orpheus-arabic-saudi
# allam-2-7b
# groq/compound-mini
# openai/gpt-oss-120b
# openai/gpt-oss-20b
# groq/compound
# whisper-large-v3-turbo
# meta-llama/llama-prompt-guard-2-22m
# whisper-large-v3
# canopylabs/orpheus-v1-english
# meta-llama/llama-prompt-guard-2-86m
# qwen/qwen3.6-27b
# openai/gpt-oss-safeguard-20b
