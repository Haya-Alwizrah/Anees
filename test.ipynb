# %%
import pandas as pd

# %%
data_path = "datasets\Formatted-MSA-prompts-stories-for-fine-tuning.csv"
dataset = pd.read_csv(data_path)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\F'
# <>:1: SyntaxWarning: invalid escape sequence '\F'
# C:\Users\haya5\AppData\Local\Temp\ipykernel_12768\3488826711.py:1: SyntaxWarning: invalid escape sequence '\F'
#   data_path = "datasets\Formatted-MSA-prompts-stories-for-fine-tuning.csv"

# %%
row = dataset["Story"]

# %%
len(row)
# Out:
# 996
