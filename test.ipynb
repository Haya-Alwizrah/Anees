# %%
import os
from src.rag import StoryGenerator

# %%
data_path = "datasets\\Formatted-MSA-prompts-stories-for-fine-tuning.csv"
groq_key = os.getenv("GROQ_KEY")
model_name = "openai/gpt-oss-20b"

# %%
sg = StoryGenerator(data_path, groq_key, model_name)

# %%
sg.prepare()
# Out:
# creat or get collection
# Loading embedding_func...
# WARNING:tensorflow:From c:\Users\computer\AppData\Local\Programs\Python\Python312\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# embedding_func loaded.
# Collection 'stories' is ready.
# BM25 index built.
# Existing collection loaded.

# %%
import random

# %%
topic = ["الصداقة", "الصدق", "التعاون", "احترام الوالدين", "مساعدة الآخرين", "المسؤولية", "التسامح", "النظافة"]
t = random.choice(topic)

character = ["أرنب", "أسد", "غزال", "نمر"]
c = random.choice(character)

# %%
story_1 = sg.generate_story(search_t=5, topic= t, character=c)
print(story_1)
# Out:
# كان أرنب اسمه فهد يعيش في حديقة خضراء مليئة بالزرع. كل صباح، كان فهد يساعد أصدقاءه في ترتيب الفواكه وتطهير الأرض. في يومٍ من الأيام، وجد فهد كومة كبيرة من القش المتراكمة في الزاوية. بدلاً من تركها، قرر فهد أن ينظفها بنفسه لأنه يعرف أن القش قد يشتعل في الصيف. جمع القش بعناية ووضعها في حاوية خاصة، ثم دعا الأصدقاء ليأخذوا القش للحديقة. أثناء العمل، سمع فهد صوتًا يصرخ من أحد الزوايا، فقد كان هناك طائر صغير عالق في شبكة. فهد استخدم قوته الصغيرة ليحرره، وأظهر أن المسؤولية لا تعني فقط تنظيف المكان بل أيضًا مساعدة الآخرين. بعد انتهاء العمل، شكر الجميع فهد وأعربوا عن فخرهم بقدراته. تعلم فهد أن الاعتماد على النفس يعني أن يكون جاهزًا لتولي المهام مهما كانت صعبة. ومنذ ذلك اليوم، أصبح فهد مثالًا للطفل المسؤول في الحديقة، ويشجع الجميع على تحمل المسؤولية.

# %%
qa = sg.generate_QA(story_1)
print(qa)
# Out:
# ```json
# {
#     "questions": [
#         {
#             "id": 1,
#             "question": "ماذا فعل فهد عندما وجد كومة القش في الزاوية؟",
#             "c_answer": "جمع القش ووضعها في حاوية خاصة",
#             "w_answer": [
#                 "ترك القش كما هو",
#                 "أكل القش",
#                 "أطلق النار على القش"
#             ]
#         },
#         {
#             "id": 2,
#             "question": "لماذا وضع فهد القش في حاوية خاصة؟",
#             "c_answer": "لمنع احتراق القش في الصيف",
#             "w_answer": [
#                 "لتزيين الحديقة",
#                 "لبيع القش في السوق",
#                 "لتغذية الحيوانات"
#             ]
#         },
#         {
#             "id": 3,
#             "question": "ماذا فعل فهد عندما سمع صوت صراخ من زاوية الحديقة؟",
#             "c_answer": "حرّر الطائر الصغير من الشبكة",
#             "w_answer": [
#                 "تجاهل الصوت",
#                 "ركب على الطائر",
#                 "غنّى مع الطائر"
#             ]
#         },
#         {
#             "id": 4,
#             "question": "ما الذي تعلمه فهد من هذه التجربة؟",
#             "c_answer": "أن يكون مسؤولاً ويعتني بالمنطقة",
#             "w_answer": [
#                 "أن يترك القش كما هو",
#                 "أن يشتري طائرًا",
#                 "أن يركض بسرعة"
#             ]
#         },
#         {
#             "id": 5,
#             "question": "ماذا فعل أصدقاء فهد بعد انتهاء العمل؟",
#             "c_answer": "شكروا فهد وأعربوا عن فخرهم بقدراته",
#             "w_answer": [
#                 "غادروا الحديقة",
#                 "أكلوا الفواكه",
#                 "تركوا الحديقة في فوضى"
#             ]
#         }
#     ]
# }
# ```

# %%
from groq import Groq
import os

client = Groq(api_key=os.getenv("GROQ_KEY"))

models = client.models.list()

for model in models.data:
    print(model.id)
# Out:
# canopylabs/orpheus-arabic-saudi
# allam-2-7b
# groq/compound-mini
# openai/gpt-oss-120b
# openai/gpt-oss-20b
# groq/compound
# whisper-large-v3-turbo
# meta-llama/llama-prompt-guard-2-22m
# whisper-large-v3
# canopylabs/orpheus-v1-english
# meta-llama/llama-prompt-guard-2-86m
# qwen/qwen3.6-27b
# openai/gpt-oss-safeguard-20b
