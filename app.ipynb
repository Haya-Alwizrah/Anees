# %%
import os
import random
from src.rag import StoryGenerator

# %%
data_path = "datasets\\Formatted-MSA-prompts-stories-for-fine-tuning.csv"
groq_key = os.getenv("GROQ_KEY")
model_name = "openai/gpt-oss-120b"

# %%
sg = StoryGenerator(data_path, groq_key, model_name)

# %%
sg.prepare()
# Out:
# creat or get collection
# Loading embedding_func...
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# embedding_func loaded.
# Collection 'stories' is ready.
# BM25 index built.
# Existing collection loaded.

# %%
topic = ["الصداقة", "الصدق", "التعاون", "احترام الوالدين", "مساعدة الآخرين", "المسؤولية", "التسامح", "النظافة"]
t = random.choice(topic)

character = ["أرنب", "أسد", "غزال", "نمر"]
c = random.choice(character)

# %%
story = sg.generate_story(search_t=5, topic= t, character=c)
print(story)
# Out:
# Loading reranker...
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# Reranker loaded.
# في قرية هادئة على حافة الغابة، كان يعيش أرنبٌ اسمه سليم. كان سليم يحب الجزر الطازج، لكنه لاحظ أن حقل الجزر الذي يزرعه يفتقر إلى الماء. فكر سليم أن يذهب إلى النبع وحده، لكنه تذكر أن الطريق طويل ومليء بالحجارة. دعا أصدقاءه: سلحفاةً اسمها مريم، وعصفورًا اسمه حسام، وثعلبًا ودودًا اسمه رائد. شرح لهم سليم أن عليهم حفر قناة صغيرة لتوصيل الماء إلى الحقل. عملت مريم ببطء لكن بثبات، فحفرَت حفرةً صغيرةً لتجمع المياه. رفع حسام الأغصان الخفيفة لتثبيت الجدران الجانبية للقناة، بينما رائد حمل الأدوات الثقيلة. بعد عدة أيام من التعاون، تدفق الماء إلى الحقل وبدأت الجزر تنمو مرةً أخرى. احتفل الجميع بحصاد الجزر، وشكر سليم أصدقاءه على جهودهم المشتركة. تعلم الأطفال في القرية أن التعاون يجعل الصعب سهلًا وأن العمل الجماعي يزرع السعادة.

# %%
ex = sg.explain_words(story)
print(ex)
# Out:
# {
#     "words": [
#         {
#             "word": "هادئة",
#             "meaning": "هادئة تعني هادئ، لا صخب ولا ضجيج"
#         },
#         {
#             "word": "حافة",
#             "meaning": "حافة تعني الطرف أو الجانب الخارجي لشيء"
#         },
#         {
#             "word": "غابة",
#             "meaning": "غابة هي مكان فيه الكثير من الأشجار"
#         },
#         {
#             "word": "طازج",
#             "meaning": "طازج يعني جديد وغير فاسد"
#         },
#         {
#             "word": "يفتقر",
#             "meaning": "يفتقر يعني لا يملك شيئًا يحتاجه"
#         },
#         {
#             "word": "نبع",
#             "meaning": "نبع هو ماء يخرج من الأرض"
#         },
#         {
#             "word": "سلحفاة",
#             "meaning": "سلحفاة حيوان يملك درعًا صلبًا على ظهره"
#         },
#         {
#             "word": "ثعلب",
#             "meaning": "ثعلب حيوان يملك فروًا أحمرًا وذيلًا طويلًا"
#         },
#         {
#             "word": "ودود",
#             "meaning": "ودود يعني لطيف ومحب"
#         },
#         {
#             "word": "قناة",
#             "meaning": "قناة هي ممر صغير للماء يجرى فيه"
#         },
#         {
#             "word": "توصيل",
#             "meaning": "توصيل يعني نقل شيء من مكان إلى آخر"
#         },
#         {
#             "word": "حفر",
#             "meaning": "حفر يعني عمل حفرة أو خندق بالحركة"
#         },
#         {
#             "word": "حفرة",
#             "meaning": "حفرة هي مساحة عميقة في الأرض"
#         },
#         {
#             "word": "تجمع",
#             "meaning": "تجمع يعني جمع الأشياء في مكان واحد"
#         },
#         {
#             "word": "الأغصان",
#             "meaning": "الأغصان هي الفروع الصغيرة للأشجار"
#         },
#         {
#             "word": "تثبيت",
#             "meaning": "تثبيت يعني جعل شيء ثابتًا ولا يتحرك"
#         },
#         {
#             "word": "الجدران",
#             "meaning": "الجدران هي الأسطح التي تشكل حدود القناة"
#         },
#         {
#             "word": "الجانبية",
#             "meaning": "الجانبية تعني على الجانب"
#         },
#         {
#             "word": "الأدوات",
#             "meaning": "الأدوات هي الأشياء التي نستخدمها للقيام بعمل"
#         },
#         {
#             "word": "الثقيلة",
#             "meaning": "الثقيلة تعني وزنها كبير"
#         },
#         {
#             "word": "تدفق",
#             "meaning": "تدفق يعني أن الماء يتحرك بسرعة إلى الأسفل"
#         },
#         {
#             "word": "حصاد",
#             "meaning": "حصاد يعني جمع الثمار أو الخضار عندما تنضج"
#         },
#         {
#             "word": "جهودهم",
#             "meaning": "جهودهم تعني ما يعملون به من عمل ومساعدة"
#         },
#         {
#             "word": "المشتركة",
#             "meaning": "المشتركة تعني التي يعمل فيها الجميع معًا"
#         },
#         {
#             "word": "الصعب",
#             "meaning": "الصعب يعني ما يحتاج إلى جهد كبير"
#         },
#         {
#             "word": "سهلًا",
#             "meaning": "سهلًا يعني ما يكون بسيطًا ولا يحتاج جهد"
#         },
#         {
#             "word": "الجماعي",
#             "meaning": "الجماعي يعني ما يفعله مجموعة من الناس معًا"
#         },
#         {
#             "word": "يزرع",
#             "meaning": "يزرع يعني يزرع نباتًا أو فكرة"
#         },
#         {
#             "word": "السعادة",
#             "meaning": "السعادة هي الشعور بالفرح والبهجة"
#         }
#     ]
# }

# %%
qa = sg.generate_QA(story)
print(qa)
# Out:
# {
#     "questions": [
#         {
#             "id": 1,
#             "question": "ما هو اسم الأرنب الذي يزرع الجزر في القصة؟",
#             "c_answer": "سليم",
#             "w_answer": [
#                 "علي",
#                 "حسن",
#                 "كريم"
#             ]
#         },
#         {
#             "id": 2,
#             "question": "أي صديق كان يرفع الأغصان لتثبيت جدران القناة؟",
#             "c_answer": "حسام",
#             "w_answer": [
#                 "مريم",
#                 "رائد",
#                 "سليم"
#             ]
#         },
#         {
#             "id": 3,
#             "question": "من هو الحيوان الذي حفر حفرة صغيرة لتجمع المياه ببطء لكن بثبات؟",
#             "c_answer": "مريم",
#             "w_answer": [
#                 "سليم",
#                 "رائد",
#                 "حسام"
#             ]
#         },
#         {
#             "id": 4,
#             "question": "لماذا قرر سليم أن يطلب مساعدة أصدقائه بدلاً من الذهاب إلى النبع وحده؟",
#             "c_answer": "لأن الطريق طويل ومليء بالحجارة",
#             "w_answer": [
#                 "لأن النبع بعيد جداً",
#                 "لأن أصدقاءه يحبون المغامرة",
#                 "لأن النبع مغلق"
#             ]
#         },
#         {
#             "id": 5,
#             "question": "ماذا تعلم الأطفال في القرية من هذه القصة؟",
#             "c_answer": "أن التعاون يجعل الصعب سهلًا",
#             "w_answer": [
#                 "أن الجزر يحتاج إلى الشمس فقط",
#                 "أن العمل الفردي أسرع",
#                 "أن الفراشات تجلب الحظ"
#             ]
#         }
#     ]
# }

# %%
llm_judge = sg.LLM_as_judge(10)
llm_judge
# Out:
# {'موافقة للموضوع': np.float64(10.0),
#  'كلمات عربية': np.float64(10.0),
#  'الترابط': np.float64(9.4),
#  'الواقعية': np.float64(8.8)}
