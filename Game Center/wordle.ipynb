# %%
import pandas as pd
import random
import re

# %%
data = pd.read_csv("..\\datasets\\Anees_Curated_Word_Bank.csv")["الكلمة"]

# %%
def normlize(word):
    word = re.sub("[\u064B-\u065F]","", word)
    word = re.sub("[أإآٱ]","ا",word)
    word = re.sub("ة","ه",word)
    word = re.sub("ة","ه",word)
    return word

# %%
word = random.choice(data)
word = normlize(word)
word
# Out:
# 'نقيق'

# %%
Attempts = 7 if len(word) > 5 else 6
guess = ""

# %%
word_t = [c for c in word]
word_t
# Out:
# ['ن', 'ق', 'ي', 'ق']

# %%
guess = input()

# %%
if len(word) != len(guess):
    print("try again")
else:
    for g in guess:
        if g in word_t:
            pass
